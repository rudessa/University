# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import ast

# %%
## Парсим информацию
url = "https://gensh.honeyhunterworld.com/"
response = requests.get(url+"fam_chars/?lang=EN")
soup = BeautifulSoup(response.text, "html.parser")

# %%
script_tag = soup.find("script", string=re.compile("sortable_data.push"))
if script_tag:
    script_text = script_tag.string

    match = re.search(
        r"sortable_data.push\(\s*(\[\[.*?\]\])\s*\);", script_text, re.DOTALL)

    if match:
        data = match.group(1)

        table_data = ast.literal_eval(data)
    else:
        print("Не удалось извлечь данные.")
else:
    print("Не найден скрипт")

# %%
data = []
stop_words = "Test", "Trial"

for character in table_data:
    string = BeautifulSoup(character[0], "html.parser")
    char_name = string.find("img").get('alt')

    if any(stop in char_name for stop in stop_words):
        continue

    data.append({})
    char_link = url+string.find("a").get("href").replace("/", "").replace("\\", "")
    char_page = requests.get(char_link)
    char_page_soup = BeautifulSoup(char_page.text, "html.parser")
    table_rows = char_page_soup.find("table", class_="genshin_table main_table").find_all("tr")

    for row in table_rows:
        cells = row.find_all("td")
        for cell in cells:
            if cell.text in ("Name", "Association", "Month of Birth", "Weapon", "Element"):
                data[-1][cell.text.lower()] = cells[-1].text.lstrip("\xa0")
            elif cell.text == "Rarity":
                data[-1]["rarity"] = len(cells[-1].find_all("img"))

# %%
traveler = data[4].copy()
traveler["association"] = None
for idx, char in enumerate(data):
    if char["name"]=="Traveler":
        del data[idx]
    elif char["association"].lower() == "fatui":
        char["association"] = "SNEZHNAYA"
    elif char["association"].lower() == "ranger":
        char["association"] = None

# %%
data_dict = {item['name']: item for item in data}
data_dict
# Out:
# {'Kamisato Ayaka': {'name': 'Kamisato Ayaka',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '9'},
#  'Jean': {'name': 'Jean',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '3'},
#  'Lisa': {'name': 'Lisa',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '6'},
#  'Barbara': {'name': 'Barbara',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '7'},
#  'Kaeya': {'name': 'Kaeya',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '11'},
#  'Diluc': {'name': 'Diluc',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '4'},
#  'Razor': {'name': 'Razor',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '9'},
#  'Amber': {'name': 'Amber',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '8'},
#  'Venti': {'name': 'Venti',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '6'},
#  'Xiangling': {'name': 'Xiangling',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '11'},
#  'Beidou': {'name': 'Beidou',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '2'},
#  'Xingqiu': {'name': 'Xingqiu',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '10'},
#  'Xiao': {'name': 'Xiao',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Anemo',
#   'month of birth': '4'},
#  'Ningguang': {'name': 'Ningguang',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Geo',
#   'month of birth': '8'},
#  'Klee': {'name': 'Klee',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Pyro',
#   'month of birth': '7'},
#  'Zhongli': {'name': 'Zhongli',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '12'},
#  'Fischl': {'name': 'Fischl',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '5'},
#  'Bennett': {'name': 'Bennett',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Pyro',
#   'month of birth': '2'},
#  'Tartaglia': {'name': 'Tartaglia',
#   'association': 'SNEZHNAYA',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '7'},
#  'Noelle': {'name': 'Noelle',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '3'},
#  'Qiqi': {'name': 'Qiqi',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '3'},
#  'Chongyun': {'name': 'Chongyun',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '9'},
#  'Ganyu': {'name': 'Ganyu',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '12'},
#  'Albedo': {'name': 'Albedo',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '9'},
#  'Diona': {'name': 'Diona',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '1'},
#  'Mona': {'name': 'Mona',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '8'},
#  'Keqing': {'name': 'Keqing',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '11'},
#  'Sucrose': {'name': 'Sucrose',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '11'},
#  'Xinyan': {'name': 'Xinyan',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '10'},
#  'Rosaria': {'name': 'Rosaria',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '1'},
#  'Hu Tao': {'name': 'Hu Tao',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '7'},
#  'Kaedehara Kazuha': {'name': 'Kaedehara Kazuha',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '10'},
#  'Yanfei': {'name': 'Yanfei',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Pyro',
#   'month of birth': '7'},
#  'Yoimiya': {'name': 'Yoimiya',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '6'},
#  'Thoma': {'name': 'Thoma',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '1'},
#  'Eula': {'name': 'Eula',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '10'},
#  'Raiden Shogun': {'name': 'Raiden Shogun',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '6'},
#  'Sayu': {'name': 'Sayu',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Anemo',
#   'month of birth': '10'},
#  'Sangonomiya Kokomi': {'name': 'Sangonomiya Kokomi',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '2'},
#  'Gorou': {'name': 'Gorou',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Geo',
#   'month of birth': '5'},
#  'Kujou Sara': {'name': 'Kujou Sara',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '7'},
#  'Arataki Itto': {'name': 'Arataki Itto',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '6'},
#  'Yae Miko': {'name': 'Yae Miko',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '6'},
#  'Shikanoin Heizou': {'name': 'Shikanoin Heizou',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '7'},
#  'Yelan': {'name': 'Yelan',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '4'},
#  'Kirara': {'name': 'Kirara',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Dendro',
#   'month of birth': '1'},
#  'Aloy': {'name': 'Aloy',
#   'association': None,
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '4'},
#  'Shenhe': {'name': 'Shenhe',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '3'},
#  'Yun Jin': {'name': 'Yun Jin',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '5'},
#  'Kuki Shinobu': {'name': 'Kuki Shinobu',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '7'},
#  'Kamisato Ayato': {'name': 'Kamisato Ayato',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '3'},
#  'Collei': {'name': 'Collei',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Dendro',
#   'month of birth': '5'},
#  'Dori': {'name': 'Dori',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '12'},
#  'Tighnari': {'name': 'Tighnari',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Dendro',
#   'month of birth': '12'},
#  'Nilou': {'name': 'Nilou',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '12'},
#  'Cyno': {'name': 'Cyno',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '6'},
#  'Candace': {'name': 'Candace',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Hydro',
#   'month of birth': '5'},
#  'Nahida': {'name': 'Nahida',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Dendro',
#   'month of birth': '10'},
#  'Layla': {'name': 'Layla',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '12'},
#  'Wanderer': {'name': 'Wanderer',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '1'},
#  'Faruzan': {'name': 'Faruzan',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '8'},
#  'Yaoyao': {'name': 'Yaoyao',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Dendro',
#   'month of birth': '3'},
#  'Alhaitham': {'name': 'Alhaitham',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Dendro',
#   'month of birth': '2'},
#  'Dehya': {'name': 'Dehya',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '4'},
#  'Mika': {'name': 'Mika',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '8'},
#  'Kaveh': {'name': 'Kaveh',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Dendro',
#   'month of birth': '7'},
#  'Baizhu': {'name': 'Baizhu',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Dendro',
#   'month of birth': '4'},
#  'Lynette': {'name': 'Lynette',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '2'},
#  'Lyney': {'name': 'Lyney',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '2'},
#  'Freminet': {'name': 'Freminet',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '9'},
#  'Wriothesley': {'name': 'Wriothesley',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '11'},
#  'Neuvillette': {'name': 'Neuvillette',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '12'},
#  'Charlotte': {'name': 'Charlotte',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '4'},
#  'Furina': {'name': 'Furina',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '10'},
#  'Chevreuse': {'name': 'Chevreuse',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '1'},
#  'Navia': {'name': 'Navia',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '8'},
#  'Gaming': {'name': 'Gaming',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '12'},
#  'Xianyun': {'name': 'Xianyun',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '4'},
#  'Chiori': {'name': 'Chiori',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '8'},
#  'Sigewinne': {'name': 'Sigewinne',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '3'},
#  'Arlecchino': {'name': 'Arlecchino',
#   'association': 'SNEZHNAYA',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '8'},
#  'Sethos': {'name': 'Sethos',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '5'},
#  'Clorinde': {'name': 'Clorinde',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '9'},
#  'Emilie': {'name': 'Emilie',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Dendro',
#   'month of birth': '9'},
#  'Kachina': {'name': 'Kachina',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '4'},
#  'Kinich': {'name': 'Kinich',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Dendro',
#   'month of birth': '11'},
#  'Mualani': {'name': 'Mualani',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '8'},
#  'Xilonen': {'name': 'Xilonen',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '3'},
#  'Chasca': {'name': 'Chasca',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '12'},
#  'Ororon': {'name': 'Ororon',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '10'},
#  'Mavuika': {'name': 'Mavuika',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '8'},
#  'Citlali': {'name': 'Citlali',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '1'},
#  'Lan Yan': {'name': 'Lan Yan',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '1'},
#  'Yumemizuki Mizuki': {'name': 'Yumemizuki Mizuki',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '3'},
#  'Iansan': {'name': 'Iansan',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '8'},
#  'Varesa': {'name': 'Varesa',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '11'},
#  'Escoffier': {'name': 'Escoffier',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '6'},
#  'Ifa': {'name': 'Ifa',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '3'},
#  'Skirk': {'name': 'Skirk',
#   'association': 'SCOURGE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '1'},
#  'Dahlia': {'name': 'Dahlia',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '1'}}

# %%
# Парсим рейтинг и роль персонажа
tier_list_url = "https://genshin.gg/tier-list/"
responce = requests.get(tier_list_url)
tier_list_soup = BeautifulSoup(responce.text, "html.parser")

# %%
zones = tier_list_soup.find_all("div", class_="dropzone-row")

alter_names = {
    "Tartaglia": "Childe"}

for zone in zones:
    rate = zone.find("div", class_=re.compile(r"^dropzone-title [A-Z]$")).text
    zone_chars = zone.find("div", "dropzone-characters --mobile d-md-none").find_all("a")

    for char in zone_chars:
        name = char.find("h2", "tierlist-name").text
        role = char.find("h3", "tierlist-role").text

        for key in data_dict.keys():
            if name in key:
                data_dict[key]["role"] = role
                data_dict[key]["power_rating"] = rate
                break

            elif "Traveler" in name:
                elem = char.find("div").find_all("img")[-1].get("alt")
                data_dict[name] = traveler.copy()
                data_dict[name]["name"] = name
                data_dict[name]["role"] = role
                data_dict[name]["power_rating"] = rate
                data_dict[name]["element"] = elem
                break

            elif key in alter_names and alter_names[key] == name:
                data_dict[key]["role"] = role
                data_dict[key]["power_rating"] = rate
                break

# %%
data_dict
# Out:
# {'Kamisato Ayaka': {'name': 'Kamisato Ayaka',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '9',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Jean': {'name': 'Jean',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Lisa': {'name': 'Lisa',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '6',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Barbara': {'name': 'Barbara',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '7',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Kaeya': {'name': 'Kaeya',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '11',
#   'role': 'Sub DPS',
#   'power_rating': 'C'},
#  'Diluc': {'name': 'Diluc',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '4',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Razor': {'name': 'Razor',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '9',
#   'role': 'Main DPS',
#   'power_rating': 'D'},
#  'Amber': {'name': 'Amber',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '8',
#   'role': 'Sub DPS',
#   'power_rating': 'D'},
#  'Venti': {'name': 'Venti',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '6',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Xiangling': {'name': 'Xiangling',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '11',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Beidou': {'name': 'Beidou',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '2',
#   'role': 'Sub DPS',
#   'power_rating': 'B'},
#  'Xingqiu': {'name': 'Xingqiu',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '10',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Xiao': {'name': 'Xiao',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Anemo',
#   'month of birth': '4',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Ningguang': {'name': 'Ningguang',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Geo',
#   'month of birth': '8',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Klee': {'name': 'Klee',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Pyro',
#   'month of birth': '7',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Zhongli': {'name': 'Zhongli',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '12',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Fischl': {'name': 'Fischl',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '5',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Bennett': {'name': 'Bennett',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Pyro',
#   'month of birth': '2',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Tartaglia': {'name': 'Tartaglia',
#   'association': 'SNEZHNAYA',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '7',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Noelle': {'name': 'Noelle',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '3',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Qiqi': {'name': 'Qiqi',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'D'},
#  'Chongyun': {'name': 'Chongyun',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '9',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Ganyu': {'name': 'Ganyu',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '12',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Albedo': {'name': 'Albedo',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '9',
#   'role': 'Sub DPS',
#   'power_rating': 'B'},
#  'Diona': {'name': 'Diona',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Mona': {'name': 'Mona',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '8',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Keqing': {'name': 'Keqing',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '11',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Sucrose': {'name': 'Sucrose',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '11',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Xinyan': {'name': 'Xinyan',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '10',
#   'role': 'Support',
#   'power_rating': 'D'},
#  'Rosaria': {'name': 'Rosaria',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Hu Tao': {'name': 'Hu Tao',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '7',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Kaedehara Kazuha': {'name': 'Kaedehara Kazuha',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '10',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Yanfei': {'name': 'Yanfei',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Pyro',
#   'month of birth': '7',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Yoimiya': {'name': 'Yoimiya',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '6',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Thoma': {'name': 'Thoma',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Eula': {'name': 'Eula',
#   'association': 'MONDSTADT',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '10',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Raiden Shogun': {'name': 'Raiden Shogun',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '6',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Sayu': {'name': 'Sayu',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Anemo',
#   'month of birth': '10',
#   'role': 'Support',
#   'power_rating': 'D'},
#  'Sangonomiya Kokomi': {'name': 'Sangonomiya Kokomi',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '2',
#   'role': 'Support',
#   'power_rating': 'A'},
#  'Gorou': {'name': 'Gorou',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Geo',
#   'month of birth': '5',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Kujou Sara': {'name': 'Kujou Sara',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '7',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Arataki Itto': {'name': 'Arataki Itto',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '6',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Yae Miko': {'name': 'Yae Miko',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '6',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Shikanoin Heizou': {'name': 'Shikanoin Heizou',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '7',
#   'role': 'Sub DPS',
#   'power_rating': 'C'},
#  'Yelan': {'name': 'Yelan',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '4',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Kirara': {'name': 'Kirara',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Dendro',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Aloy': {'name': 'Aloy',
#   'association': None,
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Cryo',
#   'month of birth': '4',
#   'role': 'Sub DPS',
#   'power_rating': 'D'},
#  'Shenhe': {'name': 'Shenhe',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'A'},
#  'Yun Jin': {'name': 'Yun Jin',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '5',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Kuki Shinobu': {'name': 'Kuki Shinobu',
#   'association': 'INAZUMA',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '7',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Kamisato Ayato': {'name': 'Kamisato Ayato',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '3',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Collei': {'name': 'Collei',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Dendro',
#   'month of birth': '5',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Dori': {'name': 'Dori',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Electro',
#   'month of birth': '12',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Tighnari': {'name': 'Tighnari',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Dendro',
#   'month of birth': '12',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Nilou': {'name': 'Nilou',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '12',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Cyno': {'name': 'Cyno',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '6',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Candace': {'name': 'Candace',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Hydro',
#   'month of birth': '5',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Nahida': {'name': 'Nahida',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Dendro',
#   'month of birth': '10',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Layla': {'name': 'Layla',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '12',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Wanderer': {'name': 'Wanderer',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '1',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Faruzan': {'name': 'Faruzan',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '8',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Yaoyao': {'name': 'Yaoyao',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Dendro',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Alhaitham': {'name': 'Alhaitham',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Dendro',
#   'month of birth': '2',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Dehya': {'name': 'Dehya',
#   'association': 'SUMERU',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '4',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Mika': {'name': 'Mika',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '8',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Kaveh': {'name': 'Kaveh',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Dendro',
#   'month of birth': '7',
#   'role': 'Main DPS',
#   'power_rating': 'D'},
#  'Baizhu': {'name': 'Baizhu',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Dendro',
#   'month of birth': '4',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Lynette': {'name': 'Lynette',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '2',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Lyney': {'name': 'Lyney',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Pyro',
#   'month of birth': '2',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Freminet': {'name': 'Freminet',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Cryo',
#   'month of birth': '9',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Wriothesley': {'name': 'Wriothesley',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '11',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Neuvillette': {'name': 'Neuvillette',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '12',
#   'role': 'Main DPS',
#   'power_rating': 'S'},
#  'Charlotte': {'name': 'Charlotte',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '4',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Furina': {'name': 'Furina',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '10',
#   'role': 'Sub DPS',
#   'power_rating': 'S'},
#  'Chevreuse': {'name': 'Chevreuse',
#   'association': 'FONTAINE',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Navia': {'name': 'Navia',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Geo',
#   'month of birth': '8',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Gaming': {'name': 'Gaming',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '12',
#   'role': 'Main DPS',
#   'power_rating': 'C'},
#  'Xianyun': {'name': 'Xianyun',
#   'association': 'LIYUE',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '4',
#   'role': 'Support',
#   'power_rating': 'A'},
#  'Chiori': {'name': 'Chiori',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '8',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Sigewinne': {'name': 'Sigewinne',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Hydro',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'A'},
#  'Arlecchino': {'name': 'Arlecchino',
#   'association': 'SNEZHNAYA',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Pyro',
#   'month of birth': '8',
#   'role': 'Main DPS',
#   'power_rating': 'S'},
#  'Sethos': {'name': 'Sethos',
#   'association': 'SUMERU',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '5',
#   'role': 'Sub DPS',
#   'power_rating': 'C'},
#  'Clorinde': {'name': 'Clorinde',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '9',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Emilie': {'name': 'Emilie',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Dendro',
#   'month of birth': '9',
#   'role': 'Sub DPS',
#   'power_rating': 'A'},
#  'Kachina': {'name': 'Kachina',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Geo',
#   'month of birth': '4',
#   'role': 'Sub DPS',
#   'power_rating': 'B'},
#  'Kinich': {'name': 'Kinich',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Dendro',
#   'month of birth': '11',
#   'role': 'Main DPS',
#   'power_rating': 'S'},
#  'Mualani': {'name': 'Mualani',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Hydro',
#   'month of birth': '8',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Xilonen': {'name': 'Xilonen',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '3',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Chasca': {'name': 'Chasca',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Bow',
#   'element': 'Anemo',
#   'month of birth': '12',
#   'role': 'Main DPS',
#   'power_rating': 'S'},
#  'Ororon': {'name': 'Ororon',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Bow',
#   'element': 'Electro',
#   'month of birth': '10',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Mavuika': {'name': 'Mavuika',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Claymore',
#   'element': 'Pyro',
#   'month of birth': '8',
#   'role': 'Main DPS',
#   'power_rating': 'S'},
#  'Citlali': {'name': 'Citlali',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Cryo',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'S'},
#  'Lan Yan': {'name': 'Lan Yan',
#   'association': 'LIYUE',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '1',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Yumemizuki Mizuki': {'name': 'Yumemizuki Mizuki',
#   'association': 'INAZUMA',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '3',
#   'role': 'Main DPS',
#   'power_rating': 'B'},
#  'Iansan': {'name': 'Iansan',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Polearm',
#   'element': 'Electro',
#   'month of birth': '8',
#   'role': 'Support',
#   'power_rating': 'B'},
#  'Varesa': {'name': 'Varesa',
#   'association': 'NATLAN',
#   'rarity': 5,
#   'weapon': 'Catalyst',
#   'element': 'Electro',
#   'month of birth': '11',
#   'role': 'Main DPS',
#   'power_rating': 'A'},
#  'Escoffier': {'name': 'Escoffier',
#   'association': 'FONTAINE',
#   'rarity': 5,
#   'weapon': 'Polearm',
#   'element': 'Cryo',
#   'month of birth': '6'},
#  'Ifa': {'name': 'Ifa',
#   'association': 'NATLAN',
#   'rarity': 4,
#   'weapon': 'Catalyst',
#   'element': 'Anemo',
#   'month of birth': '3'},
#  'Skirk': {'name': 'Skirk',
#   'association': 'SCOURGE',
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Cryo',
#   'month of birth': '1'},
#  'Dahlia': {'name': 'Dahlia',
#   'association': 'MONDSTADT',
#   'rarity': 4,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '1'},
#  'Traveler (Dendro)': {'name': 'Traveler (Dendro)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Dendro',
#   'month of birth': '0',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Traveler (Pyro)': {'name': 'Traveler (Pyro)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Pyro',
#   'month of birth': '0',
#   'role': 'Support',
#   'power_rating': 'C'},
#  'Traveler (Anemo)': {'name': 'Traveler (Anemo)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Anemo',
#   'month of birth': '0',
#   'role': 'Sub DPS',
#   'power_rating': 'D'},
#  'Traveler (Electro)': {'name': 'Traveler (Electro)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Electro',
#   'month of birth': '0',
#   'role': 'Support',
#   'power_rating': 'D'},
#  'Traveler (Geo)': {'name': 'Traveler (Geo)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Geo',
#   'month of birth': '0',
#   'role': 'Sub DPS',
#   'power_rating': 'D'},
#  'Traveler (Hydro)': {'name': 'Traveler (Hydro)',
#   'association': None,
#   'rarity': 5,
#   'weapon': 'Sword',
#   'element': 'Hydro',
#   'month of birth': '0',
#   'role': 'Support',
#   'power_rating': 'D'}}

# %%
df = pd.DataFrame(data_dict).T
df.reset_index(drop=True, inplace=True)
df[df.isnull().any(axis=1)]
# Out:
#                    name association rarity    weapon  element month of birth  \
# 46                 Aloy        None      4       Bow     Cryo              4
# 96            Escoffier    FONTAINE      5   Polearm     Cryo              6
# 97                  Ifa      NATLAN      4  Catalyst    Anemo              3
# 98                Skirk     SCOURGE      5     Sword     Cryo              1
# 99               Dahlia   MONDSTADT      4     Sword    Hydro              1
# 100   Traveler (Dendro)        None      5     Sword   Dendro              0
# 101     Traveler (Pyro)        None      5     Sword     Pyro              0
# 102    Traveler (Anemo)        None      5     Sword    Anemo              0
# 103  Traveler (Electro)        None      5     Sword  Electro              0
# 104      Traveler (Geo)        None      5     Sword      Geo              0
# 105    Traveler (Hydro)        None      5     Sword    Hydro              0
#
#         role power_rating
# 46   Sub DPS            D
# 96       NaN          NaN
# 97       NaN          NaN
# 98       NaN          NaN
# 99       NaN          NaN
# 100  Support            C
# 101  Support            C
# 102  Sub DPS            D
# 103  Support            D
# 104  Sub DPS            D
# 105  Support            D

# %%
df[df.isnull().any(axis=1)]
# Out:
#                    name association rarity    weapon  element month of birth  \
# 46                 Aloy        None      4       Bow     Cryo              4
# 96            Escoffier    FONTAINE      5   Polearm     Cryo              6
# 97                  Ifa      NATLAN      4  Catalyst    Anemo              3
# 98                Skirk     SCOURGE      5     Sword     Cryo              1
# 99               Dahlia   MONDSTADT      4     Sword    Hydro              1
# 100   Traveler (Dendro)        None      5     Sword   Dendro              0
# 101     Traveler (Pyro)        None      5     Sword     Pyro              0
# 102    Traveler (Anemo)        None      5     Sword    Anemo              0
# 103  Traveler (Electro)        None      5     Sword  Electro              0
# 104      Traveler (Geo)        None      5     Sword      Geo              0
# 105    Traveler (Hydro)        None      5     Sword    Hydro              0
#
#         role power_rating
# 46   Sub DPS            D
# 96       NaN          NaN
# 97       NaN          NaN
# 98       NaN          NaN
# 99       NaN          NaN
# 100  Support            C
# 101  Support            C
# 102  Sub DPS            D
# 103  Support            D
# 104  Sub DPS            D
# 105  Support            D

# %%
df.to_csv("genshin_data.csv")
